# %% [markdown]
# <a href="https://colab.research.google.com/github/sigvehaug/Introduction-to-Python-for-Medical-Researchers/blob/master/00-Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2021-09-06, University of Bern, Sigve Haug

# %% [markdown]
# # Introduction to Python Programming for Medical Researchers
#
# - a beginners course without any need for programming background and with examples from the medical field
# - by [Sigve Haug](https://www.scits.unibe.ch/about_us/people_metadata/pd_dr_haug_sigve/), Science IT Support, Mathematical Institute, University of Bern
# - [link to course site](https://elearning.hset.org/course/view.php?id=224)
# - 1 ETCS
# - 2 days of lectures with one homework and a small project for assessment

# %% [markdown]
# ## Who am I ?

# %% [markdown]
# ![SigveHaug.png](data:image/png;base64,...)

# %% [markdown]
# ## Who are you?
#
# 22 participants with diverse affiliations and email domains (swiss, italian, german, uk ...). Show participant list.

# %% [markdown]
# ## Motivation
#
# Python is a modern programming language which is also much used for Statistical Data Analysis and Machine Learning. It has become a core tool of choice for a wide range of researchers spanning over multiple disciplines. Also medical researcher can profit from all the advanced capabilities and automatisation possibilities not coming with spread sheets.

# %% [markdown]
# ## Learning objectives
#
# Participants can/know
# * What programming means
# * How medical researchers can work with tabular data in Python
# * Python syntax
# * Python variables and objects
# * Python operators
# * Python built-in data types and structures
# * Python control flow
# * How to define and use Python functions
# * Python strings (and regular expressions)
# * File input and output in Python
# * About Python modules and packages
# * How to read and write images with Python
# More comes for the second day

# %% [markdown]
# ##Grading and general requirements
#
# Please note that you may request an extension of the indicated deadlines below of maximum 2 weeks. Homework and assignment exercise are graded as "passed" upon successful completion.

# %% [markdown]
# ## Program
#
# * 2021-09-06 Online lectures Day 1
# * 2021-09-17 Homework due
# * 2021-09-06 Online lectures Day 2
# * 2021-09-27 Assignment exercise due

# %% [markdown]
# ## Schedule
#
# Day 1
# * 09:00 - 09:15 Welcome
# * 09:15 - 09:45 Working with Jupyter notebooks
# * 09:45 - 10:30 Case study 1 with medical data
# * 10:30 - 11:00 Break
# * 11:00 - 12:00 Working with Python 1 (chapters 1-6)
# * 12:00 - 13:00 Exercise 1
# * 12:30 - 13:30 Lunch
# * 13:30 - 14:00 Discussion
# * 14:00 - 15:00 Case study 2 with medical data (images?)
# * 15:00 - 15:30 Break
# * 15:30 - 16:30 Working with Python 2 (chapter 7, 8, 9, 14 and 15)
# * 16:30 - 16:45 Exercise 2 - homework for day 2 (working on the filesystem from Python)
# * 16:45 - 17:00 Day 1 wrap up and feedback
#
# Day 2
# * 09:00 - 09:30 Discussion on content from day 1 and exercise 2
# * 09:30 - 10:30 Case study 3 - medical images with NumPy
# * 10:30 - 11:00 Break
# * 11:00 - 12:00 Working with NumPy 1 (chapter 2)
# * 12:00 - 12:30 Exercise 3
# * 12:30 - 13:30 Lunch
# * 13:30 - 14:00 Discussion
# * 14:00 - 15:00 Working with NumPy 2 (chapter 2)
# * 15:00 - 15:30 Break
# * 15:30 - 16:00 Exercise 4
# * 16:00 - 16:30 Discussion
# * 16:15 - 16:45 Outlook (common data science modules for Python)
# * 16:45 - 17:00 Course wrap up and feedback

# %% [markdown]
# ## Communication
#
# Pleaes use the [course forum](https://elearning.hset.org/mod/forum/view.php?id=9331) for discusscions. Organisational and any other matters can be directed to the course coordinator or the lecturer.

# %% [markdown]
# ## Platforms
#
# We use the course web, the github repository of the course and google colab for running the notebooks and exercises.

# %% [markdown]
# ## Any questions
#
# * Before we start?

# %% [markdown]
# ## Monty Python - Have Fun !

# %% [markdown]
# <center>
#
# <img src="https://github.com/sigvehaug/Introduction-to-Python-Programming-For-Medical-Researchers/blob/master/IntroductorySlides/ImagesVideos/MPython.jpg?raw=1" width="500">
# </center>
